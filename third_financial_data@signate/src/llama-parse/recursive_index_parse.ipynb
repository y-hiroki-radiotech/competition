# %% [markdown]
# #### Llama-parseでPDFを読み込み、Markdown形式に保存してみる

# %%
import nest_asyncio
from dotenv import load_dotenv

nest_asyncio.apply()
load_dotenv()
# Out:
# True

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings

embed_model = OpenAIEmbedding(model="text-embedding-3-large")
llm = OpenAI(model="gpt-3.5-turbo-0125")

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# #### Using LlamaParse PDF reader for PDF Parsing
#
# 1. raw Markdown textをインデックス構築のノードとして使用し、結果を生成するためのシンプルなクエリエンジンを適用する
# 2. MarkdownElementNodeParserを使用して、LlamaParse出力のMarkdown結果を解析し、生成用の再帰的な取得クエリエンジンを構築する

# %%
from llama_parse import LlamaParse

documents = LlamaParse(result_type="markdown").load_data("1.pdf")
# Out:
# WARNING: parsing_instruction is deprecated. Use complemental_formatting_instruction or content_guideline_instruction instead.
# Started parsing the file under job_id ba057fc2-7184-4d9f-856e-2074ab7f740b
# .

# %%
len(documents)
# Out:
# 14

# %%
from copy import deepcopy
from llama_index.core.schema import TextNode
from llama_index.core import VectorStoreIndex

def get_page_nodes(docs, separator="\n---\n"):
    """Split each document into page node, by separator."""
    nodes = []
    for doc in docs:
        doc_chunks = doc.text.split(separator)
        for doc_chunk in doc_chunks:
            node = TextNode(
                text=doc_chunk,
                metadata=deepcopy(doc.metadata)
            )
            nodes.append(node)
    return nodes

# %%
page_nodes = get_page_nodes(documents)

# %%
len(page_nodes)
# Out:
# 14

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(
    llm=OpenAI(model="gpt-4o-mini"),
    num_workers=8
)

# %%
nodes = node_parser.get_nodes_from_documents(documents)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 7219.11it/s]
# 0it [00:00, ?it/s]
# 2it [00:00, 1988.29it/s]
# 1it [00:00, 8256.50it/s]
# 1it [00:00, 7244.05it/s]
# 1it [00:00, 17848.10it/s]
# 2it [00:00, 18001.30it/s]
# 1it [00:00, 7145.32it/s]
# 0it [00:00, ?it/s]
# 3it [00:00, 6380.79it/s]
# 18it [00:00, 57151.76it/s]
# 6it [00:00, 60640.54it/s]
# 0it [00:00, ?it/s]

# %%
len(nodes)
# Out:
# 125

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
base_nodes[1].get_content()
# Out:
# '経営理念・ブランドコンセプト\n\n ４℃ホールディングスグループの\n\n At a Glance\n\n Corporate Philosophy 経営理念\n\n私達は、お客様に信頼される企業を目指します。\n\n私達は、社員に夢を与える企業を目指します。\n\n私達は、社会に貢献できる企業を目指します。\n\n私達は、株主に期待される企業を目指します。\n\n Corporate Message コーポレートメッセージ\n\n当グループは、4℃ブランドを中心としたグローバルファッション創造企業として、お客様の一歩先のニーズに応える、お客様の生活文化を向上させる企業であり続けます。\n\n 業績（2024年月期）'

# %%
objects[1].get_content()
# Out:
# "This table presents key statistics related to a company's workforce, including the number of subsidiaries, employee training hours, total employees, female management ratio, training expenses, and performance against government gender equality targets.,\nwith the following columns:\n- 連結子会社数: Number of consolidated subsidiaries.\n- 年間教育研修: Total annual training hours.\n- 総時間: Total hours (not specified).\n- 従業員数（連結）: Total number of consolidated employees.\n- 女性管理職比率: Percentage of female managers.\n- 年間教育研修費: Annual training expenses.\n- 政府目標の「女性管理職比率 30%」を上回る: Indicates whether the company exceeds the government target for female management ratio.\n"

# %%
page_nodes
# Out:
# [TextNode(id_='60d9a38e-b137-4bba-8776-1958c17ffb30', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 統 合レポート\n\n# ４℃\n\n# レポート 2024\n\nすべては、お客様の “笑顔” や “ときめき” のために', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='0009b274-b3f7-42d7-81a1-7f568673e7c2', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 経営理念・ブランドコンセプト\n\n# ４℃ホールディングスグループの\n\n# At a Glance\n\n# Corporate Philosophy 経営理念\n\n私達は、お客様に信頼される企業を目指します。\n\n私達は、社員に夢を与える企業を目指します。\n\n私達は、社会に貢献できる企業を目指します。\n\n私達は、株主に期待される企業を目指します。\n\n# Corporate Message コーポレートメッセージ\n\n当グループは、4℃ブランドを中心としたグローバルファッション創造企業として、お客様の一歩先のニーズに応える、お客様の生活文化を向上させる企業であり続けます。\n\n# 業績（2024年月期）\n\n|売上高|394.5億円（前期比△0.1%）|\n|---|---|\n|営業利益|20.9億円（前期比＋5.9%）|\n|当期純利益|13.0億円（前期比＋13.2%）|\n|株主数|31,465名|\n|１株当たり配当金|83円|\n|100円配当の実現を目指す| |\n\n# 業員の状況（2024年月29日現在）\n\n|連結子会社数|7社|\n|---|---|\n|年間教育研修|27,398時間|\n|総時間| |\n|従業員数（連結）|1,003名|\n|女性管理職比率|32.4 %|\n|年間教育研修費|40.9百万円|\n|政府目標の「女性管理職比率 30%」を上回る| |\n\n# Brand Concept『４℃』ブランドコンセプト\n\n水は自由奔放に、その姿を変えていきます。\n\n時には繊細な光を放つ雪の結晶のように、また時には大きなうねりとなって大海原へ。\n\nそして、岩や大地をも削り取る強い結束力さえもあります。\n\n水は平凡どころか、すこぶる非凡であり、シンプルにしてきわめて強固。\n\nそれは、地球上のあらゆる生命に潤いをもたらせています。\n\n「水のようでありたい」それが私たちのモノづくりの原点になっています。\n\n# ブランド業\n\n「４℃」それは氷が張った水面の底の温度をあらわします。\n\n唯一魚が生息できるいわば「安息の場」であり、きびしい環境にあっての潤いそのものを意味します。\n\n私たちは既存の価値に捉われることなく常に新しさと潤いをもたらす商品の提案を続けています。\n\n# ジュエリーブランド数\n\n6ブランド\n\n# 店舗数\n\n「パレット」104店舗136店舗\n\n# 会員数\n\n47万人115万人\n\n# 目次\n\n1. ４℃ホールディングスグループの At a Glance\n2. サステナビリティ戦略\n3. トップメッセージ\n4. 価値創造ストーリー\n5. ４℃ホールディングスの歩み\n6. ４℃ホールディングスグループの価値創造プロセス\n7. リスクと機会、マテリアリティ\n8. 経営理念の実践\n9. 役員一覧\n\n株式会社４℃ホールディングス\n\n４℃レポート 2024', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='d42c191b-94f1-4795-9203-8a4d0b3623df', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# トップメッセージ\n\n「まっとうな経営」を軸に、見直しを進めます。アパレル事業では、「パレット」で毎期約10店舗の出店を継続し、売上高の拡大を図ります。関東エリアへの出店を成功させるために、豊富で魅力的な品揃えにより、お客様への提供価値を一層高めてまいります。\n\n# 成長基盤を構築していきます\n\n企業の持続的成長を支える人財投資\n\n当社グループが、これまでさまざまな挑戦を重ねて今日まで存続することができた背景には、人財を育て、人を大切にする組織風土を育むことに注力してきたことが非常に大きいと考えています。\n\n当社グループでは教育を、期待と愛情を伝えるための手段の一つとして捉えています。2022年度には、持続的に人を育てるための継続した教育を、世代を超えて実施していくために、人財育成・教育制度を体系化いたしました。\n\n創業より長年にわたり継承されてきた教育への想いを形にした、当グループ独自の人財育成プログラムであり、まさにサステナブル経営の根幹である『人財』に対する当グループの姿勢を表わすものであると考えております。\n\n# 事業活動を通じた社会への貢献\n\n当社グループは、お客様、社員、お取引先様、地域社会、そして株主様との強い信頼関係や絆により支えられて発展してまいりました。第8次中期経営計画以降では、強固な基盤を活かし事業町域の拡大を図り、飛躍的な成長を実現していく計画です。\n\n社会・事業環境が非連続に変化していくなかで、常にお客様の一歩先のニーズを探り、応え続けていくこと、そして、社員一人一人が仕事を通じて成長し、価値創造により社会に貢献できる、そういう企業グループを、これからも目指してまいります。\n\n皆様におかれましては、今後ともより一層のご支援ご鞭撻を賜りますよう、お願い申しあげます。\n\n# 挑戦し続ける企業風土\n\n「人間尊重」「社会貢献」。４℃ホールディングスグループは、1950年の創業以来、脈々と受け継がれてきたこの基本理念のもと、お客様の生活文化の向上を使命に掲げ、時代とともに進化し続けることで、ファッション業界の川上から川下までさまざまな事業活動を展開してまいりました。\n\n「４℃」ブランドを中心に展開するブランド事業、アパレルOEMODMと総合衣料品店「パレット」をチェーン展開するアパレル事業を両輪に、コロナ禍のような非常事態においても安定した経営状態で乗り切ることができました。\n\n# 第7次中期経営計画の基本方針\n\n（対象期間：2025年月期～2027年月期のカ年）\n\n# Challenge for Future 未来への挑戦～2030年に向けて～\n\n『環境変化への対応』を前提に『顧客提供価値』を追求し、将来の飛躍に向けた成長基盤を構築していきます。\n\n# 第7次中期経営計画の重点取り組みについて\n\n2024年度からスタートした第7次中期経営計画では、中核であるブランド事業では、「４℃」ブランドがお客様へ提供する価値を具現化し、「４℃」ブランドの輝きを増すことで、事業価値を高め、高収益ビジネスモデルを再構築してまいります。\n\n# 資本収益性向上への取り組み\n\n成長戦略\n\n≪事業戦略の推進≫\n\n- ファッションジュエリーの再構築（商品構成・MDの刷新）\n- ECチャネルの拡充\n- OMO戦略の推進\n\n# 第8次中期経営計画以降の成長フェーズにつなげる\n\n- アパレル事業、パレットの出店拡大継続\n- 機動的な自己株式の取得\n- M&A、海外展開、新規事業など成長資の実行\n- 安定的かつ継続的な配当\n- 顧客化の深耕\n- 飛躍的な利益成長による資本効率の向上\n- 保有株式の売却\n\n追求し、将来の飛躍に向けた成長基盤を構築していきます。\n\n株式会社４℃ホールディングス\n\n４℃レポート 2024', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='63b3fcb7-7d83-48a3-8f9a-5ad5ab8b0498', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 価値創造ストーリー\n\n# ４℃ホールディングスの歩み\n\n株式会社４℃ホールディングスは、1950年、繊維製品の販売を目的とした「十和織物株式会社」として広島市に設立され、翌1951年に「十和株式会社」に商号変更しました。\n\nその後、1986年にジュエリーのＳＰＡを展開する子会社として「株式会社エフ・ディ・シィ・プロダクツ」を設立し、1991年には「十和株式会社」を「株式会社アスティ」に商号変更。1996年、小売業の「株式会社アージュ」を設立するなど、事業領域を拡大してきました。\n\nそして2006年、株式会社アスティと株式会社エフ・ディ・シィ・プロダクツの共同持株会社である「株式会社 F&Аアクアホールディングス」を設立し、2013年に現在の「株式会社４℃ホールディングス」に商号変更しました。\n\n現在、当社グループは「株式会社４℃ホールディングス」および子会社7社で構成され、「４℃」ジュエリーを中心としたブランド事業、ODMを中心としたアパレルメーカー事業、総合衣料品店「パレット」をチェーン展開するデイリーファッション事業からなる強固な事業ポートフォリオのもと、持続性のある成長モデルを描いています。\n\n# グループ組織図\n\n|（株）４℃ホールディングス|（株）エフ・ディ・シィ・プロダクツ|（株）アスティ|（株）アージュ|\n|---|---|---|---|\n|子会社として「株式会社フジ」設立|関係会社|関係会社|特例子会社|\n|（株）エフ・ディ・シィ・フレンズ|（株）アロックス|（株）ハートフルアクア|（株）アスコット|\n\n# 主な連結子会社\n\n|社名|事業内容|\n|---|---|\n|（株）エフ・ディ・シィ・プロダクツ|ジュエリー等の企画・製造・販売|\n|（株）アスティ|衣料品、服飾品の企画・製造・販売等|\n|（株）アージュ|衣料品、生活雑貨等の販売|\n|（株）ハートフルアクア|物流、商品検品、ビジネスサポート等|\n|（株）アロックス|物流業務の受託等|\n|（株）アスコット|ベビー服等の企画・製造・販売|\n|（株）エフ・ディ・シィ・フレンズ|ジュエリー等の販売|', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='a8267af4-be15-48d2-aee8-e0cfb574b0af', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 価値創造ストーリー\n\n# ４℃ホールディングスグループの価値創造プロセス\n\n４℃ホールディングスグループは、ブランド事業やアパレル事業など顧客層の異なる多彩なポートフォリオを構築することで、社会・事業環境が非連続に変化していくなかでも安定した経営状態を維持してきました。これからもそれぞれの事業領域について独自性と強みを発揮することで、さまざまな社会課題を解決し、社会的・経済的価値を創出してまいります。\n\n|インプット（2024年月期）|強み|ビジネスモデル|アウトプット（2024年2月期）|アウトカム（2024年月末時点）|\n|---|---|---|---|---|\n|財務資本|ブランド事業|多様な事業を展開することで、安定した事業ポートフォリオを構築|売上高|財務資本|\n|純資産|38,596百万円|売上構成比|・ TЅR 106.8％|・ DOЕ 4.6％|\n|人的資本|顧客基盤|グループ従業員数 1,003人|他平均臨時雇用者数 1,164人|男女賃金格差 72.8％|\n|知的資本|登録商標数|156件|海外 60件|女性管理職比率 32.4％|\n|社会・関係資本|主要取引先（睦会・パートナー会） 136社|店舗数 237店舗|物流拠点 3拠点|離職率 26.9％|\n|自然資本|電力使用量 3,479千 kWh|CO 排出量 86,481t-CO2|営業利益 2,096百万円|店舗数 7店舗減少|\n\n# 中期経営計画\n\n第 6次中期経営計画は2024年2月期で終了。現在推進中の第次中期経営計画（2025年月期～2027年2月期）において、Chаllеngе for Futurе 未来への挑戦～2030年に向けて～」をテーマに掲げ、「環境変化への対応」を前提に「顧客提供価値」を追求し、将来の飛躍に向けた成長基盤の構築に取り組む。\n\n# 成長投資分野\n\n盤石な財務基盤のもと、持続的成長に向け約 36億円の成長投資を実行。\n\n# 注\n\n外部顧客に対する売上高を表示しています。', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='cf7941c3-1768-4a3e-90e5-dddc104ddf62', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 価値創造ストーリー\n\n# リスクと機会、マテリアリティ\n\n4℃ホールディングスグループは、社会課題から事業に対するリスクと機会を特定し、重要な経営課題（マテリアリティ）を特定しました。特定したマテリアリティは中長期的課題として全社を挙げて取り組んでまいります。\n\n# 外部環境課題\n\n|リスクと機会| | |社会的価値の創造|マテリアリティ|主な施策| |КРІと目標|現状（2024年月期）|関連するSDGsゴール| | | | | |\n|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|\n|物価高による仕入れコスト・物流コストの上昇|国内マーケットの縮小| | |生活文化の向上|パレットマーケット拡大|連結売上高|394.5億円|2030年度未開示| | | | | | |\n|人口減少・婚姻組数の減少による|脱炭素社会への移行への遅れによる|環境負荷の削減| | | | | | | | |生産管理力と企画提案力の強化|連結営業利益|20.9億円| |\n| |戦争やテロ等に起因するサプライチェーンの断絶|為替の変動や資源高による財務状況の悪化|消費者に残る価格抑制圧力|人的資本経営の実践|CO₂排出量|86,481t-CO₂|2050年度ネットゼロ| | | | | | | |\n| |物価高騰による節約志向の高まり|採用競争の激化や離職率の高まりによる|生物多様性の保全|資源循環の拡大|CO₂排出量削減率|（Scope1,2 2021年度比）|2030年度▲50%| | | | | | | |\n|人財の不足|機会|成長余地のある国内・海外のマーケット|再生エネルギー比率|2030年度50%| | | | | | | | | | |\n|社会全体の賃上げ要請|消費者へのECでの買い物の浸透|物価高騰による低価格マーケットのニーズ拡大| | | |女性管理職比率| | |32.4%|2030年度40%|人財育成| | | |\n|インバウンド消費の拡大|サステナビリティに対する意識の高まり|IT技術の進化| | | | | | | | | |離職率|26.9%|2030年度15%|\n|労働力の減少| | |経営理念の実践|ウェルビーイング|従業員の健康|男性育休取得率|0.0%|2030年度100%| | | | | | |\n| | | | | |ワークライフバランスの向上|人権デューデリジェンス|グループ実施状況|DOÉ（株主資本配当率）|4.6%|2030年度4%以上| | | | |\n| | | | | |コンプライアンスの徹底|コーポレートガバナンス|適切な株主還元|ROE|ROE|4.7%|2030年度8%以上| | | |\n\n株式会社４℃ホールディングス\n\n４℃レポート 2024', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='df2e45de-504a-41a5-b9ba-52682883241d', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# サステナビリティ戦略\n\n# 社会価値の創造\n\n# 生活文化の向上\n\n# ブランド事業～ブランド価値向上への取り組み\n\n「４℃」ブランドが創造する提供価値\n\n価値観に「４℃」ブランドをアジャストし、ファッション性を高めていくことで、身に着ける女性にとって、自分らしさを表現できる商品を提案していきます。\n\nデイリーファッション「パレット」は、暮らしを、ファッションを楽しみたいというお客様のために、いつも楽しい商品とサービスを提供し続ける、地域に愛されるお店作りを目指しています。\n\n# アパレル事業～マーケットの更なる拡大\n\n「４℃」を中心に展開するブランド事業では、主にジュエリーの生産・企画・販売を通じて、身に着ける女性の心を満たすジュエリーを世に送り出してきました。\n\n1972年の「４℃」ブランド誕生から50年以上もの間、多くの方に愛され、いくつもの喜びの瞬間に寄り添い、お客様の人生とともに輝き続けてきました。\n\n# ブランドビジネスにとって最も大切なものは信用であり、それは一朝一夕で築くことはできません。\n\n私たちは、品質へのこだわり、ホスピタリティあふれる接客サービスを一貫して継続することで、ブランドビジネスを拡大してきました。\n\n# 「４℃」ブランドの価値向上による「100年ブランド」の実現\n\n「100年ブランド」を掲げる「４℃」は、第7次中期経営計画にて、これからの50年の提供価値づくりに取り組みます。\n\n# 「パレット」売上高と店舗数の計画\n\n|売上高（百万円）|店舗数（店舗）|\n|---|---|\n|20,000|140|\n|18,400|129|\n|15,200|129|\n|12,000|120|\n|10,000|109|\n|8,000|99|\n\n# EC 売上高\n\n売上高（百万円）2,5002,4372,2422,004\n\n# 「４℃」の主要チャネルである百貨店が高級品やインバウンド需要が牽引し、好調に推移するなか、当社も高価格帯への対応を強化します。\n\n# お客様の体験価値向上のために進化を続け、更なる成長を図ります。', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='abeb52bf-e7b9-47c6-aca1-3a01cc212899', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# サステナビリティ戦略\n\n# 環境負荷の軽減\n\n# 気候変動への対応\n\n# 気候変動～戦略\n\n基本方針\n\nサステナビリティに関する課題について、当社グループは経営基盤を支える重要課題と捉え、2021年度に「サステナビリティ基本方針」を制定しました。\n\n当社グループでは、異なるシナリオ（2℃未満、4℃）における財務影響および事業インパクトを評価するとともに、気候変動リスク・機会に対する当社戦略のレジリエンスを評価することを目的として、2030年を見据えたシナリオ分析を実施しています。\n\n「サステナビリティ基本方針」では「環境」「調達」「人権」「人財」の4つの方針を掲げ、事業を通じた持続可能な社会の実現に向けた取り組みを進めています。そのなかで、環境負荷の軽減に対する取り組みをマテリアリティの一つとして認識し、『環境方針』のもと、GHG（温室効果ガス）削減をはじめとする気候変動への対応に積極的に取り組んでいます。\n\n# 具体的な取り組み\n\n|区分|当社に可能性のある事項|4℃シナリオ|2℃未満シナリオ|当社の対応方針|\n|---|---|---|---|---|\n|政策|炭素税の導入によるコストの増大|中|大|脱炭素・低炭素エネルギーの利用促進|\n|法規制|情報開示義務拡大への対応による業務負荷、コストの増大|小|中|開示業務の効率化|\n|排出量削減|商品LCА（ライフサイクルアセスメント）評価義務化によるトレーサビリティの確保等必要な措置による業務負荷とコストの増大|-|中|新たな業務範囲の精査および業務の効率化|\n|移行リスク|市場リスク|大|大|調達先の安定的な確保と付加価値の追求による利益率の確保|\n|急性リスク|台風や大雨により店舗が営業できないことによる売上減少|中|小|事業継続計画の策定|\n|慢性リスク|冬物衣料の需要低下による売上減少のリスク|大|中|気温に合わせたマーチャンダイジングの変更|\n\n当社グループは2050年度までにGHG（温室効果ガス）排出量（Scope1、2、3）のネットゼロ実現へ向けて、具体的な取り組みを進めています。2022年度には本社ビルおよび（株）エフ・ディ・シィ・プロダクツの品質管理センター、工房で使用する電力を再生エネルギーへ切り替えを行いました。\n\n当社は、2030年度までに再生エネルギー導入比率50％を目指しており、今後も店舗およびグループ会社施設等の再生エネルギーへの切り替えを推進していきます。\n\nその他、店舗におけるLED照明の使用や省エネ、ペーパーレス化の促進にも積極的に取り組んでいます。また、より実態に即した排出量の算出に近づけ、サプライチェーン全体での排出量を削減するため、お取引先様との連携にも取り組んでいます。\n\n# TCFD の枠組みに沿った情報開示\n\n当社は、2023年1月、金融安定理事会（FSB）設立の「気候関連財務情報開示タスクフォース（TCFD）」提言に賛同しました。気候変動が当社の事業に与える可能性のあるリスクと機会を把握し、これらに適切に対応することを目的に、「ガバナンス」「リスク管理」「戦略」「指標と目標」の4つの開示項目に沿った情報開示に取り組んでいます。\n\n# 温室効果ガス排出量\n\n|項目|2022年月期|2023年2月期|2024年月期|2051年月期までにネットゼロ|\n|---|---|---|---|---|\n|温室効果ガスScope123|73,479.0 tCO₂|82,715.5 tCO₂|86,481.1 tCO₂|2|\n|Scope12|2,279.4 tCO₂|22,181.5 tCO₂|-|50％|\n\n※影響度の判定：売上・利益・資産が1％以上変動する可能性があるものを「大」、0.5%以上変動する可能性があるものを「中」、それ以外を「小」と判定しています。\n\n一般社団法人「morе trееs（モア・トゥリーズ）」は、音楽家・坂本龍一氏が創立し、建築家・隈研吾氏が代表を務める森林保全団体です。「都市と森をつなぐ」をキーワードに、さまざまな取り組みを行っています。', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='2c4e8afd-3076-473c-a5bd-b62016bd217a', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# サステナビリティ戦略\n\n# 人的資本経営の実践\n\n# 人財育成\n\n# 経営人財養成\n\n# 事業価値向上\n\n基本方針\n\n当社グループは「サステナビリティ基本方針」において、人間尊重を基本理念に掲げ、「人財」こそが当社グループ最大の財産であるとの認識のもと、多様な人財の育成に積極的に取り組むことで、企業価値を高めるとともに、持続可能な社会の実現を目指しています。\n\n次世代リーダーの育成を目的として、グループの課長以上を対象に、参加メンバーが経営者視点で自社の課題や将来ビジョンを発表する「若手経営者懇談会」、教育・研修を行っています。\n\n事業価値を高める能力開発と専門スキルの向上を目的とした「℃ホールディングス スクール「アドバンスト・スクール」、そして「女性活躍支援プログラム」の3つの教育プログラムを実施しています。\n\nまた、教育プログラムや研修、OJTを通じて従業員の能力開発とキャリア形成を促す機会や環境を提供しています。\n\n当社は2030年度女性管理職比率40.0％を目標に掲げています。この目標の達成に向け、「女性活躍支援プログラム」では、女性の社外取締役が講師となった勉強会の実施や、各種社外セミナーへの参加、担当役員との1on1ミーティングにより、視座を高め、管理職としてのステップアップを図る取り組みを行っています。\n\n「人的資本経営」という言葉がまだ世の中に浸透する以前から、こうした考えに基づき取り組んできた「人財育成」は、当社グループにとって、もっとも大切な価値観の一つです。\n\n# 具体的な取り組み\n\n教育体系\n\n持続的に人を育てるための継続した教育を、世代を超えて実施していくために、『人財育成・教育』を体系化しています。\n\n# ４℃ホールディングスグループ教育体系図\n\n|階層|目的|\n|---|---|\n|役員|次世代リーダーの育成|\n|部長|アドバンスト・スクール|\n|課長|女性活躍支援プログラム|\n|MG/C|考課者訓練|\n|6～10年目|ビジネススクール|\n|2～年目|well-being|\n|新入社員|主に（株）４℃ホールディングス|\n\n人的資本経営を実践していくために、従業員一人ひとりの健康は必要不可欠であると考えています。また、テレワーク制度の導入や、残業時間の削減によるワークライフバランスの向上、男性育児休暇の取得促進にも積極的に取り組んでいきます。\n\n当社グループで働くすべての従業員が、肉体的な健康だけでなく、「身体・精神・社会的に満たされた状態」でいきいきと働ける環境を目指し、仕事を通じた自己実現と成長の支援、働きやすい職場づくり、多様性や個性の尊重等、さまざまなアプローチから取り組みを推進しています。\n\n株式会社４℃ホールディングス\n\n４℃レポート 2024', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='cbf28f55-2a44-42b8-b1f5-128b753d91d6', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# サステナビリティ戦略\n\n# 経営理念の実践\n\n# 人権尊重\n\n# コーポレートガバナンス\n\n基本方針\n\n人権尊重は、経営理念を実践するうえで、当社グループの根幹となるマテリアリティです。\n\n当社グループの「人権方針」では、当社グループの企業活動に関わるすべての人の人権を尊重することを宣言し、以下の項目を大切にしています。\n\n- ◼あらゆる差別・ハラスメントの撤廃\n- ◼強制労働、児童労働および人身取引の排除\n- ◼人権侵害の加担回避\n\n具体的な取り組み\n\n# ハラスメント防止\n\n当社は、個人の基本的人権と個性や多様性を尊重するとともに、人種、民族、国籍、性別、年齢、宗教、言語、障がいの有無、性的指向、性自認等に基づくあらゆる差別およびハラスメントを行いません。\n\nハラスメントの防止に向けて、全従業員を対象に、加害者にも被害者にもならないためのリテラシー向上と具体的な対応を学ぶハラスメント研修を、毎年実施しています。\n\nまた、当社グループの企業活動の中で発生した事案について、従業員だけでなく、お取引先様からも相談いただける窓口を社内・社外にそれぞれ設置し、すべての人が安心して働ける環境づくりを行っています。\n\n# 人権デューデリジェンス\n\n人権に関するコミットメント（（株）４℃ホールディングス「人権方針」・（株）エフ・ディ・シィ・プロダクツ「購買基本方針」）に基づき、ステークホルダーごとの人権リスクを特定、アセスメントの実施と、リスク防止・軽減のためのアクション、情報公開によるステークホルダーとのコミュニケーションに取り組んでいます。\n\n# コーポレートガバナンス体制の概要\n\n取締役会の実効性評価\n\n（株）エフ・ディ・シィ・プロダクツでは、企業活動全体において関わるすべての人々の人権を尊重するため、人権デューデリジェンスを実施しています。\n\n持続的な成長と企業価値の最大化を実現するためには、取締役会の実効性を高めることが極めて重要であると考えています。\n\n監査等委員会設置会社の選択（コンプライアンスの徹底）\n\n当社は、取締役会の監督機能の強化によるコーポレートガバナンスの一層の充実という観点から、自ら業務執行をしない社外取締役の機能を活用することで、中長期的な企業価値向上を図るため、監査等委員会設置会社を選択しています。\n\n監査等委員会は毎月定例にて開催するほか、必要に応じて臨時監査等委員会を開催し、代表取締役その他の業務執行取締役の業務執行を監査し、内部統制システムの構築・運用の状況を監視および検証しています。\n\n# 評価の項目\n\n1. 取締役会の運営面について（開催頻度や所要時間、資料構成、情報提供等）\n2. 取締役会の議題面について（議題選定や定例報告等）\n3. 取締役会の機能面について（多角的な検討や議論の充実度等）\n\n株主・投資家の皆様との建設的な対話は、当社グループの持続的な成長と中長期的な企業価値の向上に必要不可欠なものであると認識し、対話の充実に努めています。\n\nアナリスト・機関投資家の皆様に対しては、代表取締役社長をメインスピーカーとした年2回の決算説明会を実施しています。\n\nコーポレートガバナンスに関する詳細は「コーポレートガバナンス報告書」をご覧ください。\n\nhttps://yondoshi.co.jp/wordpress/wp-content/uploads/2024/06/20240607_CGReport.pdf', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='8de7cde6-de43-452c-a2bc-ac1c19412717', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 役員一覧 2024年5月30日現在\n\n|氏名|当社における地位|所有する当社の株式数|取締役会への出席回数（出席率）|\n|---|---|---|---|\n|増田英紀|代表取締役社長|12,900株|18/18回（100％）|\n|岡藤一朗|代表取締役専務|24,000株|18/18回（100％）|\n|西村政彦|常務取締役|19,400株|18/18回（100％）|\n|新井宏|取締役執行役員|1,700株|‒|\n|児玉直樹|社外取締役|‒|18/18回（100％）|\n|嵩下昌宏|取締役（監査等委員）|3,000株|18/18回（100％）|\n|北川展子|社外取締役（監査等委員）|‒|18/18回（100％）|\n|河添博|社外取締役（監査等委員）|‒|‒|\n\n# 経歴\n\n|氏名|経歴|\n|---|---|\n|増田英紀|1997 年 4 月 弁護士登録 2003 年 5 月 （株）アージュ入社 2015 年 3 月 同社取締役常務執行役員 2017 年 3 月 当社執行役員アージュ担当 2021 年 3 月 当社常務執行役員社長室長 2022 年 3 月 当社代表取締役社長（現）|\n|岡藤一朗|1978 年 4 月 東京国税局入局 1997 年 4 月 あすか総合法律事務所（現 隼あすか法律事務所）弁護士 2017 年 7 月 課税第一部次長 2018 年 7 月 麹町税務署長 2021 年 5 月 （株）エフ・ディ・シィ・プロダクツ監査役（現）|\n|西村政彦|1993 年 4 月 当社入社 2005 年 3 月 当社財務部長 2008 年 5 月 当社取締役 2015 年 3 月 当社取締役執行役員財務担当 2022 年 5 月 当社常務取締役常務執行役員財務担当 2024 年 3 月 当社常務取締役 常務執行役員 業務担当（現）|\n|新井宏|1985 年 4 月 当社入社 2008 年 3 月 （株）アスティアパレル一部長 2015 年 3 月 （株）エフ・ディ・シィ・プロダクツ取締役執行役員 2022 年 5 月 （株）エフ・ディ・シィ・プロダクツ常務取締役 常務執行役員 財務担当|\n|児玉直樹|1978 年 4 月 日本 IBM（株）入社 2002 年 4 月 JBCC（株）専務取締役 2007 年 8 月 （株）ニトリ常務取締役 2012 年 10月 （株）カインズ常務取締役 2018 年 3 月 当社執行役員経営企画室長|\n|嵩下昌宏|1985 年 4 月 （株）三井銀行（現 （株）三井住友銀行）入行 2009 年 4 月 SMBCフレンド証券（株）法人業務企画室長 2018 年 2 月 当社入社 2021 年 3 月 （株）ソフトクリエイトホールディングス社外取締役|\n|北川展子|2021 年 1 月 北川展子法律事務所弁護士（現）|\n|河添博|2021 年 5 月 当社取締役（監査等委員）（現）|\n\n# スキル・マトリックス\n\n|氏名|企業経営・戦略策定|業界経験（ブランド）|業界経験（海外）|業界経験（リテール）|法務・リスクマネジメント|財務・会計・M&A|人財マネジメント|デジタル・IT|CSR/E&S|\n|---|---|---|---|---|---|---|---|---|---|\n|増田 英紀|○|○| | | |○| | | |\n|岡藤 一朗|○|○|○|○| |○|○| | |\n|西村 政彦|○| |○| | |○| | | |\n|新井 宏|○|○| | | | | | | |\n|児玉 直樹|○|○| |○|○| | | | |\n|嵩下 昌宏| |○| | | | | | | |\n|北川 展子| |○| | | | | | | |\n|河添 博| |○| | | | | | | |', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='70d4aa59-23fd-4bfd-b0d2-72bea697bfc5', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# データセクション\n\n# 非財務情報\n\n# 社会：人財\n\n# 従業員数（正規雇用）\n\n|カテゴリー|項目|対象|単位|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|女性|従業員数（正規雇用）|人| |1,066|1,006|846|\n|男性|正社員・契約社員|人| |185|176|157|\n|合計| |人| |1,251|1,182|1,003|\n\n# 従業員数（有期雇用）\n\n|女性|従業員数（有期雇用）|人| |30|35|43|\n|---|---|---|---|---|---|---|\n|男性|臨時雇用社員|人| |30|35|43|\n|合計| |人| |793|1,036|1,164|\n\n# 平均勤続年数\n\n|女性|平均勤続年数|年| |7.7|8.4|8.7|\n|---|---|---|---|---|---|---|\n|男性| |年| |12.9|13.5|13.3|\n|合計| |年| |7.7|8.4|8.7|\n\n# 平均年齢\n\n|女性|平均年齢|歳| |32.9|33.7|34.1|\n|---|---|---|---|---|---|---|\n|男性|正社員・契約社員|歳| |42.2|42.8|42.7|\n|合計| |歳| |32.9|33.7|34.1|\n\n# 人財 従業員平均給与\n\n|男性|従業員平均給与|千円| |5,254|5,255|5,531|\n|---|---|---|---|---|---|---|\n|合計| |千円| |3,402|3,593|3,771|\n|女性| |千円| |34|28|24|\n\n# 管理職者数\n\n|男性|管理職者数| | |55|89|53|\n|---|---|---|---|---|---|---|\n|女性| | | |77|40|59|\n|合計| | | |132|129|112|\n\n# 新卒採用者数\n\n|男性|新卒採用者数|人| |7|8|4|\n|---|---|---|---|---|---|---|\n|合計| |人| |83|48|63|\n\n# 新卒3年後定着率\n\n|3年前の新卒社員|新卒3年後定着率|％| |68.3|55.9|52.7|\n|---|---|---|---|---|---|---|\n|女性| |人| |16|83|73|\n\n# 中途採用者数\n\n|男性|中途採用者数|人| |7|7|9|\n|---|---|---|---|---|---|---|\n|合計| |人| |23|90|82|\n\n# 従業員の離職率\n\n正社員・契約社員\n従業員の離職率\n％\n\n15.1\n22.1\n26.9\n# 年間教育研修総時間（内外含む）\n\n年間教育研修総時間（内外含む）\n時間\n\n20,718\n27,398\n17,907\n# 1人当たり年間研修時間\n\n1人当たり年間研修時間\n\n16.6\n23.6\n17.9\n# 教育研修費（外注費）\n\n教育研修費（外注費）\n千円\n\n58,151\n40,920\n41,225\n# 1人当たり年間教育費（外注費）\n\n1人当たり年間教育費（外注費）\n\n47\n35\n41\n# 会社満足度\n\n会社満足度\n\n3.1\n3.3\n3.3\n# 仕事満足度\n\n正社員\n仕事満足度\n\n3.4\n3.3\n3.3\n# 従業員満足度\n\n従業員満足度\n\n3.4\n3.7\n3.7\n# 職場満足度\n\nアスティ・アージュ\n職場満足度\n点\n\n3.3\n3.5\n3.5\n# 評価給与妥当性\n\n正社員\n評価給与妥当性\n\n2.7\n2.8\n2.7\n# 研修充実度\n\n研修充実度\n\n3.3\n3.6\n3.6\n# 女性従業員比率\n\n正社員・契約社員\n女性従業員比率\n％\n\n85.2\n85.1\n84.4\n# 女性管理職比率\n\n課長職以上\n女性管理職比率\n\n36.2\n33.8\n32.4\n# 男女の賃金差異\n\n|有期雇用従業員|男女の賃金差異|％| |(未算出)|74.0|65.0|\n|---|---|---|---|---|---|---|\n|合計| |％| |(未算出)|48.9|45.7|\n\n# 育児休業制度利用者数\n\n|男性|育児休業制度利用者数|人| |0|2|0|\n|---|---|---|---|---|---|---|\n|合計| |人| |79|86|62|\n\n# 育児休業取得率\n\n|男性|育児休業取得率|％| |0.0|33.3|0.0|\n|---|---|---|---|---|---|---|\n|合計| |％| |94.0|95.5|93.8|\n\n# 育児短時間勤務制度利用者数\n\n育児短時間勤務制度利用者数\n\n138\n174\n133\n# 子の看護休暇取得者数\n\n|女性|子の看護休暇取得者数|人| |(未算出)|(未算出)|144|\n|---|---|---|---|---|---|---|\n|男性| |人| |(未算出)|(未算出)|5|\n|合計| |人| |(未算出)|(未算出)|149|\n\n# ダイバーシティ\n\n|男性|ダイバーシティ|人| |0|0|1|\n|---|---|---|---|---|---|---|\n|女性| |人| |0|0|1|\n|合計| |人| |0|0|2|\n\n# 介護休職制度利用者数\n\n|男性|介護休職制度利用者数|人| |0|0|0|\n|---|---|---|---|---|---|---|\n|合計| |人| |0|0|1|\n\n# 介護休暇取得者数\n\n介護休暇取得者数\n\n0\n0\n1\n# 再雇用者比率\n\n正社員\n再雇用者比率\n％\n\n25.0\n33.3\n40.0\n# 外国人従業員数\n\n|男性|外国人従業員数|人| |4|3|5|\n|---|---|---|---|---|---|---|\n|合計| |人| |10|8|7|\n|女性| |人| |7|10|7|\n\n# 契約社員から正社員への登用数\n\n|男性|契約社員から正社員への登用数|人| |1|0|3|\n|---|---|---|---|---|---|---|\n|合計| |人| |8|10|10|\n|女性| |人| |16|18|20|\n\n# 障碍者雇用数\n\n|男性|障碍者雇用数|人| |18|12|12|\n|---|---|---|---|---|---|---|\n|合計| |人| |34|30|32|\n\n# 障碍者雇用率\n\n全社員\n障碍者雇用率\n\n1.9\n1.8\n1.6\n# 国内法定健康診断受診率\n\n国内法定健康診断受診率\n％\n\n79.2\n75.4\n89.6\n# ストレスチェック回答率\n\nストレスチェック回答率\n\n94.0\n93.9\n94.7\n# 年間平均総実労働時間\n\n年間平均総実労働時間\n時間\n\n1,779.6\n1,809.3\n1,842.8\n# 月間平均残業時間\n\n月間平均残業時間\n\n3.2\n4.7\n4.7\n# 有給休暇平均取得日数\n\n正社員・契約社員\n有給休暇平均取得日数\n日\n\n10.9\n11.6\n12.0\n# 有給休暇平均取得率\n\n有給休暇平均取得率\n％\n\n58.5\n70.4\n68.8\n# 株式会社４℃ホールディングス\n\n# ４℃レポート 2024', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='4a361df5-4d6a-48b8-8cd9-68fe25e5fb57', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# データセクション\n\n# 財務情報\n\n# 主要財務データ\n\n# 6カ年の推移\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|売上高 （百万円）|47,118|44,970|39,449|38,123|39,508|39,457|\n|売上総利益 （百万円）|27,155|25,780|21,294|19,672|19,727|19,530|\n|販売費及び一般管理費 （百万円）|22,171|21,804|18,527|17,884|17,748|17,433|\n|営業利益 （百万円）|4,984|3,975|2,767|1,788|1,979|2,096|\n|経常利益 （百万円）|6,804|4,312|3,195|2,293|2,342|2,515|\n|親会社株主に帰属する当期純利益 （百万円）|2,440|2,475|1,622|1,490|1,149|1,300|\n\n# 財政状態\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|総資産（百万円）|60,284|53,737|53,000|56,884|50,211|50,643|\n|純資産（百万円）|43,587|39,588|39,543|42,917|38,214|38,596|\n|有利子負債（百万円）|175|82.0|0.0|0.0|0.0|0.0|\n\n# キャッシュフロー\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|営業活動によるキャッシュ・フロー（百万円）|1,664|2,433|6,633|1,871|3,103|2,666|\n|投資活動によるキャッシュ・フロー（百万円）|△|△|△|△|△|△|\n|フリーキャッシュ・フロー（百万円）|7,071|2,506|4,463|1,977|732|1,563|\n\n# 1株当たり情報\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|１株当たり当期純利益（円）|96.03|112.18|75.00|69.56|53.61|60.65|\n|１株当たり純資産（円）|1,883.30|1,822.10|1,844.69|2,001.22|1,780.71|1,798.49|\n|１株当たり年間配当金（円）|75.00|80.00|81.00|83.00|83.00|83.00|\n\n# 財務指標\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|売上高営業利益率（％）|10.6|8.8|7.0|4.7|5.0|5.3|\n|ROA：総資産当期純利益率（％）|3.9|4.3|3.0|2.7|2.1|2.6|\n|ROE：株主資本当期純利益率（％）|5.0|6.0|4.1|3.6|2.8|3.4|\n|自己資本比率（％）|72.6|73.5|74.6|75.4|76.0|76.2|\n|有利子負債比率（％）|0.3|0.2|0.0|0.0|0.0|0.0|\n\n# 投資指標\n\n|項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|\n|---|---|---|---|---|---|---|\n|株価収益率（PER)（倍）|22.5|18.4|24.6|24.6|32.5|31.3|\n|株価純資産倍率（PBR（倍）|1.1|1.1|1.0|0.9|1.0|1.1|\n|株主総利回り（比較指標：配当込みTOPIX）|98.8|92.6|90.4|95.5|106.8|―|\n\n# 注\n\n1. 「収益認識に関する会計基準」（企業会計基準第29号2020年3月31日）等を2023年2月期の期首から適用しており、2023年2月期以降に係る各数値については当該会計基準等を適用した後の数値となっています。\n2. 2023年2月期より、不動産賃貸収入については「売上高」、不動産賃貸費用については「売上原価」に計上する方法に変更しております。\n3. フリーキャッシュ・フロー＝営業活動によるキャッシュ・フロー＋投資活動によるキャッシュ・フロー（百万円）\n4. ROA総資本当期純利益率＝当期純利益÷期首・期末平均総資産×100（%）\n5. ROE株主資本当期純利益率＝当期純利益÷期首・期末平均株主資本×100（%）\n6. 自己資本比率＝純資産÷総資産×100（%）\n7. 有利子負債比率＝〔短期有利子負債＋長期有利子負債〕÷総資産×100（%）\n8. 株価収益率＝期末株価÷1株当たり当期純利益（倍）\n9. 株価純資産倍率＝期末株価÷1株当たり純資産（倍）\n\n# Web サイトのご案内\n\n４℃ホールディングスのIRサイトでは、企業活動全般にわたる最新の情報をご提供しております。また、メールアドレスを登録いただいた方に随時情報配信を行っております。ぜひご覧ください。\n\nURL: https://yondoshi.co.jp/\n\n# IR お問い合わせ先\n\nTEL: 03-5719-3295\n\nE-mail: ir-yondoshi@yondoshi.co.jp\n\n# コーポレートガバナンス・ガイドラインについて\n\nコーポレートガバナンスに対する基本的な考え方や取り組みを体系化したものを『コーポレートガバナンス・ガイドライン』としてまとめ、コーポレートサイトへ掲載しております。当社グループは、健全で透明性の高い企業グループとして社会の信頼と責任に応えてまいります。\n\nURL: https://yondoshi.co.jp/company/governance/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='15dc2b14-81c0-45f2-ac07-e27670c1033e', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# 株式会社４℃ホールディングス\n\n〒141-0021 東京都品川区上大崎2-19-10\n\nТЕL03-5719-3429 FАХ03-5719-4462\n\nhttрѕ://уоndоѕhі.со.јр/', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}')]

# %%
# dump both indexed tables and page text into the vector index
recursive_index = VectorStoreIndex(nodes=base_nodes + objects + page_nodes)

# %%
print(page_nodes[12].get_content())
# Out:
# # データセクション
#
# # 財務情報
#
# # 主要財務データ
#
# # 6カ年の推移
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |売上高 （百万円）|47,118|44,970|39,449|38,123|39,508|39,457|
# |売上総利益 （百万円）|27,155|25,780|21,294|19,672|19,727|19,530|
# |販売費及び一般管理費 （百万円）|22,171|21,804|18,527|17,884|17,748|17,433|
# |営業利益 （百万円）|4,984|3,975|2,767|1,788|1,979|2,096|
# |経常利益 （百万円）|6,804|4,312|3,195|2,293|2,342|2,515|
# |親会社株主に帰属する当期純利益 （百万円）|2,440|2,475|1,622|1,490|1,149|1,300|
#
# # 財政状態
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |総資産（百万円）|60,284|53,737|53,000|56,884|50,211|50,643|
# |純資産（百万円）|43,587|39,588|39,543|42,917|38,214|38,596|
# |有利子負債（百万円）|175|82.0|0.0|0.0|0.0|0.0|
#
# # キャッシュフロー
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |営業活動によるキャッシュ・フロー（百万円）|1,664|2,433|6,633|1,871|3,103|2,666|
# |投資活動によるキャッシュ・フロー（百万円）|△|△|△|△|△|△|
# |フリーキャッシュ・フロー（百万円）|7,071|2,506|4,463|1,977|732|1,563|
#
# # 1株当たり情報
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |１株当たり当期純利益（円）|96.03|112.18|75.00|69.56|53.61|60.65|
# |１株当たり純資産（円）|1,883.30|1,822.10|1,844.69|2,001.22|1,780.71|1,798.49|
# |１株当たり年間配当金（円）|75.00|80.00|81.00|83.00|83.00|83.00|
#
# # 財務指標
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |売上高営業利益率（％）|10.6|8.8|7.0|4.7|5.0|5.3|
# |ROA：総資産当期純利益率（％）|3.9|4.3|3.0|2.7|2.1|2.6|
# |ROE：株主資本当期純利益率（％）|5.0|6.0|4.1|3.6|2.8|3.4|
# |自己資本比率（％）|72.6|73.5|74.6|75.4|76.0|76.2|
# |有利子負債比率（％）|0.3|0.2|0.0|0.0|0.0|0.0|
#
# # 投資指標
#
# |項目|2019年2月期|2020年2月期|2021年2月期|2022年2月期|2023年2月期|2024年2月期|
# |---|---|---|---|---|---|---|
# |株価収益率（PER)（倍）|22.5|18.4|24.6|24.6|32.5|31.3|
# |株価純資産倍率（PBR（倍）|1.1|1.1|1.0|0.9|1.0|1.1|
# |株主総利回り（比較指標：配当込みTOPIX）|98.8|92.6|90.4|95.5|106.8|―|
#
# # 注
#
# 1. 「収益認識に関する会計基準」（企業会計基準第29号2020年3月31日）等を2023年2月期の期首から適用しており、2023年2月期以降に係る各数値については当該会計基準等を適用した後の数値となっています。
# 2. 2023年2月期より、不動産賃貸収入については「売上高」、不動産賃貸費用については「売上原価」に計上する方法に変更しております。
# 3. フリーキャッシュ・フロー＝営業活動によるキャッシュ・フロー＋投資活動によるキャッシュ・フロー（百万円）
# 4. ROA総資本当期純利益率＝当期純利益÷期首・期末平均総資産×100（%）
# 5. ROE株主資本当期純利益率＝当期純利益÷期首・期末平均株主資本×100（%）
# 6. 自己資本比率＝純資産÷総資産×100（%）
# 7. 有利子負債比率＝〔短期有利子負債＋長期有利子負債〕÷総資産×100（%）
# 8. 株価収益率＝期末株価÷1株当たり当期純利益（倍）
# 9. 株価純資産倍率＝期末株価÷1株当たり純資産（倍）
#
# # Web サイトのご案内
#
# ４℃ホールディングスのIRサイトでは、企業活動全般にわたる最新の情報をご提供しております。また、メールアドレスを登録いただいた方に随時情報配信を行っております。ぜひご覧ください。
#
# URL: https://yondoshi.co.jp/
#
# # IR お問い合わせ先
#
# TEL: 03-5719-3295
#
# E-mail: ir-yondoshi@yondoshi.co.jp
#
# # コーポレートガバナンス・ガイドラインについて
#
# コーポレートガバナンスに対する基本的な考え方や取り組みを体系化したものを『コーポレートガバナンス・ガイドライン』としてまとめ、コーポレートサイトへ掲載しております。当社グループは、健全で透明性の高い企業グループとして社会の信頼と責任に応えてまいります。
#
# URL: https://yondoshi.co.jp/company/governance/

# %%
recursive_index

# %%
from llama_index.postprocessor.cohere_rerank import CohereRerank

reranker = CohereRerank(top_n=5)

# %%
recursive_query_engine = recursive_index.as_query_engine(
    similarity_top_k=5,
    node_postprocessors=[reranker],
    verbose=True
)

# %% [markdown]
# ### Setup Baseline

# %%
from llama_index.core import SimpleDirectoryReader

reader = SimpleDirectoryReader(input_files=["1.pdf"])
base_docs = reader.load_data()
raw_index = VectorStoreIndex.from_documents(base_docs)

raw_query_engine = raw_index.as_query_engine(
    similarity_top_k=5,
    node_postprocessors=[reranker],
)

# %%
query = "第7次中期経営計画のテーマは何ですか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# 第7次中期経営計画のテーマは「Challenge for Future」です。
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Challenge for Future 未来への挑戦～2030年に向けて～

# %%
query = "４℃ホールディングスの2024年2月期の売上高はいくらですか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# 13,597億円
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 394.5億円

# %%
query = "４℃ホールディングスグループの連結子会社数はいくつありますか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# 18社
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 7社

# %%
query = "４℃ホールディングスの2024年2月期の1株当たり年間配当金はいくらですか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# 1株当たり年間配当金は80円です。
# Retrieval entering bc8b1fbe-399b-4403-a39c-0eb6d1d0306c: TextNode
# Retrieving from object TextNode with query ４℃ホールディングスの2024年2月期の1株当たり年間配当金はいくらですか？
# Retrieval entering 4d1d9527-0960-425f-93de-23ff24f22149: TextNode
# Retrieving from object TextNode with query ４℃ホールディングスの2024年2月期の1株当たり年間配当金はいくらですか？
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 83円

# %%
query = "2024年2月期の従業員の平均年齢は男女それぞれ何歳ですか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# The average age of male employees for the fiscal year ending in February 2024 is 39 years old, and the average age of female employees is 37 years old.
# Retrieval entering 5f3a4a99-c7fa-4ee4-b46f-72c7462cc5c0: TextNode
# Retrieving from object TextNode with query 2024年2月期の従業員の平均年齢は男女それぞれ何歳ですか？
# Retrieval entering 301b9ec2-77f2-40d9-9547-9f6b036b337a: TextNode
# Retrieving from object TextNode with query 2024年2月期の従業員の平均年齢は男女それぞれ何歳ですか？
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 32.9歳（女性）および42.7歳（男性）

# %%
query = "2024年2月期の従業員の平均勤続年数は、男女それぞれ何年ですか？"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# The average length of service for employees in the fiscal year ending in February 2024 is 6.5 years for male employees and 7.2 years for female employees.
# Retrieval entering 301b9ec2-77f2-40d9-9547-9f6b036b337a: TextNode
# Retrieving from object TextNode with query 2024年2月期の従業員の平均勤続年数は、男女それぞれ何年ですか？
# Retrieval entering b1be35dc-21a7-4b92-8dfb-c2c1f88a8699: TextNode
# Retrieving from object TextNode with query 2024年2月期の従業員の平均勤続年数は、男女それぞれ何年ですか？
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 男性の平均勤続年数は13.3年であり、女性の平均勤続年数は8.7年です。
